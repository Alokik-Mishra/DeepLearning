# %% [markdown]
# # ECBM E4040 Assignment 2 - Task 2: Regularizations
#
# In this task, you are going to experiment with two popular regularization methods.
#
# ** Dropout:** In the last assignment, you have trained a shallow network and everything looked fine. However, when the network becomes larger and deeper, it will also become harder to train. The first potential problem is over-fitting, that is, the network overreacts to noise or random errors of the training data, while it fails to detect the underlying distribution pattern. It is more likely to occur when the model becomes complex and contains more trainable parameters. Dropout is a well-known method that can eliminate such effects. The core idea behind it is quite simple, ie., rather than updating all trainable parameters each time, it randomly selects a subset of parameters to update and keeps other parameters unaltered.
#
#
#
# ** Batch normalization:** Batch normalization makes it possible to train a deep network. When a network becomes deeper, the distribution of hidden neurons' values will also shift greatly, and that is one reason that makes it hard to train a deep neural network. Machine learning teaches that normalization is a good preprocessing method to deal with such a problem. So  batch normalization deploys a similar idea in the neural network. It re-normalizes the hidden values of each layer before transfering values to the next layer.
#
#
# * References
#     * https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
#     * https://arxiv.org/pdf/1502.03167.pdf
#     * https://www.tensorflow.org/api_docs/python/tf/contrib/layers/batch_norm
#     * https://github.com/tensorflow/tensorflow/blob/r1.3/tensorflow/contrib/layers/python/layers/layers.py
#     * https://www.tensorflow.org/api_docs/python/tf/nn/batch_normalization

# %%
# Import modules
from __future__ import print_function
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from ecbm4040.cifar_utils import load_data

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load Data

# %%
# Load the raw CIFAR-10 data.
X_train, y_train, X_test, y_test = load_data()
X_val = X_train[:500,:]
y_val = y_train[:500]
X_train = X_train[500:2500,:]
y_train = y_train[500:2500]

mean_image = np.mean(X_train, axis=0).astype(np.float32)
X_train = X_train.astype(np.float32) - mean_image
X_val = X_val.astype(np.float32) - mean_image

# We've vectorized the data for you. That is, we flatten the 32×32×3 images into 1×3072 Numpy arrays.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
# Out:
# ./data/cifar-10-python.tar.gz already exists. Begin extracting...
# Training data shape:  (2000, 3072)
# Training labels shape:  (2000,)
# Validation data shape:  (500, 3072)
# Validation labels shape:  (500,)

# %% [markdown]
# ## Part 1: Dropout

# %% [markdown]
# ### Implement dropout foward function

# %%
x_in = np.random.randn(500, 500) + 10

# %%
from ecbm4040.reg_funcs import dropout_forward
from ecbm4040.reg_funcs import dropout_backward

p = 0.5
dropout_config = {"enabled": True, "keep_prob": p}
# feedforward
out, cache = dropout_forward(x=x_in, dropout_config=dropout_config, mode="train")
out_test, _ = dropout_forward(x=x_in, dropout_config=dropout_config, mode="test") 
# backward
dout = np.ones_like(x_in)
dx = dropout_backward(dout, cache)

# Check forward correctness
print("mean_of_input = {}".format(p*np.mean(x_in)))
print("mean_of_out = {}".format(np.mean(out)))
print("mean_of_out_test = {}".format(np.mean(out_test)))
# Out:
# mean_of_input = 5.000685248985176
# mean_of_out = 9.990889502613571
# mean_of_out_test = 10.001370497970353

# %% [markdown]
# ### Experiments with MLP

# %%
from ecbm4040.neuralnets.mlp import MLP 
from ecbm4040.optimizers import AdamOptim

# %%
dropout_config = {"enabled":True, "keep_prob": 1}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_no_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.286, new learning rate = 0.00095
# epoch 2: valid acc = 0.256, new learning rate = 0.0009025
# epoch 3: valid acc = 0.286, new learning rate = 0.000857375
# epoch 4: valid acc = 0.332, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.318, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.306, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.356, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.318, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.32, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.316, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.298, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.318, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.32, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.304, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.31, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.324, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.33, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.33, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.334, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.358, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.1
dropout_config = {"enabled":True, "keep_prob": 0.1}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
hist_p1_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.206, new learning rate = 0.00095
# epoch 2: valid acc = 0.24, new learning rate = 0.0009025
# epoch 3: valid acc = 0.258, new learning rate = 0.000857375
# epoch 4: valid acc = 0.21, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.256, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.246, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.26, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.258, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.242, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.244, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.246, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.308, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.288, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.302, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.328, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.302, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.302, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.314, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.348, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.348, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.5
dropout_config = {"enabled":True, "keep_prob": 0.5}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
hist_p5_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.266, new learning rate = 0.00095
# epoch 2: valid acc = 0.308, new learning rate = 0.0009025
# epoch 3: valid acc = 0.35, new learning rate = 0.000857375
# epoch 4: valid acc = 0.298, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.336, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.328, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.334, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.314, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.314, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.338, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.338, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.348, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.326, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.33, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.378, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.334, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.366, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.328, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.334, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.352, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.7
dropout_config = {"enabled":True, "keep_prob": 0.7}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
hist_p7_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.242, new learning rate = 0.00095
# epoch 2: valid acc = 0.324, new learning rate = 0.0009025
# epoch 3: valid acc = 0.322, new learning rate = 0.000857375
# epoch 4: valid acc = 0.318, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.33, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.352, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.316, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.344, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.346, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.33, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.296, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.324, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.338, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.312, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.324, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.322, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.334, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.356, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.344, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.326, new learning rate = 0.0003584859224085418

# %%
# keep prob 0.9
dropout_config = {"enabled":True, "keep_prob": 0.9}
model = MLP(input_dim=3072, hidden_dims=[200], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, dropout_config=dropout_config)
optimizer = AdamOptim(model)
hist_p9_dropout = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=20, batch_size=100, learning_rate=1e-3, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.282, new learning rate = 0.00095
# epoch 2: valid acc = 0.314, new learning rate = 0.0009025
# epoch 3: valid acc = 0.31, new learning rate = 0.000857375
# epoch 4: valid acc = 0.318, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.324, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.31, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.3, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.33, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.31, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.312, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.292, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.306, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.306, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.322, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.316, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.314, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.308, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.348, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.33, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.346, new learning rate = 0.0003584859224085418

# %%
# plot loss curve
loss_hist_no_drop, train_acc_hist_no_drop, val_acc_hist_no_drop = hist_no_dropout
loss_hist_p1_dropout, train_acc_hist_p1_dropout, val_acc_hist_p1_dropout = hist_p1_dropout
loss_hist_p5_dropout, train_acc_hist_p5_dropout, val_acc_hist_p5_dropout = hist_p5_dropout
loss_hist_p7_dropout, train_acc_hist_p7_dropout, val_acc_hist_p7_dropout = hist_p7_dropout
loss_hist_p9_dropout, train_acc_hist_p9_dropout, val_acc_hist_p9_dropout = hist_p9_dropout

plt.plot(loss_hist_no_drop, label="No drop")
plt.plot(loss_hist_p1_dropout, label="0.1 drop")
plt.plot(loss_hist_p5_dropout, label="0.5 drop")
plt.plot(loss_hist_p7_dropout, label="0.7 drop")
plt.plot(loss_hist_p9_dropout, label="0.9 drop")
plt.legend()
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss comparision")
plt.savefig("images/dropout_loss.png")
plt.show()

# %%
# plot train acc
plt.plot(train_acc_hist_no_drop, label="No drop")
plt.plot(train_acc_hist_p1_dropout, label="0.1 drop")
plt.plot(train_acc_hist_p5_dropout, label="0.5 drop")
plt.plot(train_acc_hist_p7_dropout, label="0.7 drop")
plt.plot(train_acc_hist_p9_dropout, label="0.9 drop")
plt.legend()
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.title("Accuracy comparision")
plt.savefig("images/dropout_accuracy.png")
plt.show()

# %%
# plot val acc
plt.plot(val_acc_hist_no_drop, label="No drop")
plt.plot(val_acc_hist_p1_dropout, label="0.1 drop")
plt.plot(val_acc_hist_p5_dropout, label="0.5 drop")
plt.plot(val_acc_hist_p7_dropout, label="0.7 drop")
plt.plot(val_acc_hist_p9_dropout, label="0.9 drop")
plt.legend()
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.title("Validation accuracy comparision")
plt.savefig("images/dropout_accuracy_validation.png")
plt.show()

# %% [markdown]
# From the above we see, as expected that trying to regularize through dropout almost always results in higher training error (bias). This also seems somewhat proportional to the probability of inclusion, where as p goes to 1, the training error starts to resemble the no dropout training error. </break>
# On the other hand, we see that we generally get a better validation error when 0.5 < p < 0.9. However even with p = 0.1 which is a very low probability, we do evetually catch up to the no dropout error.

# %% [markdown]
# ## Part 2: Batch Normalization

# %% [markdown]
# ### Implement batch normalization foward function

# %%
from ecbm4040.reg_funcs import bn_forward
from ecbm4040.reg_funcs import bn_backward

np.random.seed(4040)
N, D, H1, H2 = 200, 10, 5, 3
x_in = np.random.randn(N, D)
w1 = np.random.randn(D,H1)
w2 = np.random.randn(H1,H2)
a2 = np.maximum(x_in.dot(w1),0).dot(w2)

# Before batch normalization
print("mean of a2: ", np.mean(a2, axis=0))
print("var of a2: ", np.var(a2, axis=0))

# After batch normalization, the mean should be close to zero and var should be close to one. 
bn_config = {"epsilon":1e-5, "decay":0.9}
gamma = np.ones(H2)
beta = np.zeros(H2)
a2_bn, _ = bn_forward(a2, gamma, beta, bn_config, "train")
print("(train) mean of a2_bn: ", np.mean(a2_bn, axis=0))
print("(train) var of a2_bn: ", np.var(a2_bn, axis=0))
# Out:
# mean of a2:  [ 1.79186704 -1.67375614 -0.40317141]
# var of a2:  [19.78665186  3.35093598  6.67922991]
# (train) mean of a2_bn:  [ 3.23630012e-16  1.64868119e-16 -5.46437895e-17]
# (train) var of a2_bn:  [0.99999949 0.99999702 0.9999985 ]

# %%
bn_config = {"epsilon":1e-5, "decay":0.9}
gamma = np.ones(H2)
beta = np.zeros(H2)

# collect_data: for calculating real mean and var of a2 later.
collect_data = a2
for _ in range(100):
    x_in = np.random.randn(N, D)
    a2 = np.maximum(x_in.dot(w1),0).dot(w2)
    collect_data = np.concatenate((collect_data, a2), axis=0)
    bn_forward(a2, gamma, beta, bn_config, "train")

# compare moving_mean and moving_var with real mean and var.
# You should see that they are close to each other.
print("real mean of data: ", np.mean(collect_data, axis=0))
print("(real var of data: ", np.var(collect_data, axis=0))
print("moving mean of data: ", bn_config["moving_mean"])
print("(moving var of data: ", bn_config["moving_var"])

# After bn_forward, the mean and var of output should be kind of close to gamma and beta.
x_in = np.random.randn(N, D)
a2 = np.maximum(x_in.dot(w1),0).dot(w2)
print("*"*80)
print("mean of a2: ", np.mean(a2, axis=0))
print("var of a2: ", np.var(a2, axis=0))
a2_bn, _ = bn_forward(a2, gamma, beta, bn_config, "test")
print("(test) mean of a2_bn: ", np.mean(a2_bn, axis=0))
print("(test) var of a2_bn: ", np.var(a2_bn, axis=0))
# Out:
# real mean of data:  [ 1.666064   -1.60740475 -0.77169187]
# (real var of data:  [16.11643755  2.63509026  6.64151552]
# moving mean of data:  [ 1.68347874 -1.61213737 -0.78307063]
# (moving var of data:  [16.53922597  2.69276532  6.83992499]
# ********************************************************************************
# mean of a2:  [ 1.87970734 -1.62498121 -1.06240607]
# var of a2:  [13.59580536  2.85173111  5.97719192]
# (test) mean of a2_bn:  [ 0.04825081 -0.00782699 -0.10680708]
# (test) var of a2_bn:  [0.82203346 1.05903047 0.87386677]

# %%
# After verifying the forward function and save the bn_config.
x_in = np.random.randn(N, D)
a2 = np.maximum(x_in.dot(w1),0).dot(w2)
da2_bn = np.ones_like(a2)

#bn_config = {"eps":1e-5, "decay":0.9, "moving_mean":moving_mean, "moving_var":moving_var}
gamma = np.ones(H2)
beta = np.zeros(H2)
a2_bn, cache = bn_forward(a2, gamma, beta, bn_config, "test")
da2, dgamma, dbeta = bn_backward(da2_bn, cache)

# Checking code below.
a2_tf = tf.Variable(a2)
eps = bn_config["epsilon"]
mean_tf = bn_config["moving_mean"]
var_tf = bn_config["moving_var"]
gamma_tf = tf.Variable(gamma)
beta_tf = tf.Variable(beta)
a2_bn_tf = tf.nn.batch_normalization(a2_tf, mean_tf, var_tf, beta_tf, gamma_tf, eps)
# derive gradients
da2_tf = tf.gradients(a2_bn_tf, a2_tf)
dgamma_tf = tf.gradients(a2_bn_tf, gamma_tf)
dbeta_tf = tf.gradients(a2_bn_tf, beta_tf)

init = tf.global_variables_initializer()
tf_output = (a2_bn_tf, da2_tf[0], dgamma_tf[0], dbeta_tf[0])
with tf.Session() as sess:
    sess.run(init)
    a2_bn_check, da2_check, dgamma_check, dbeta_check = sess.run(tf_output)
    
# Make comparison
print("Is a2_bn correct? {}".format(np.allclose(a2_bn, a2_bn_check)))
print("Is da2 correct? {}".format(np.allclose(da2, da2_check)))
print("Is dgamma correct? {}".format(np.allclose(dgamma, dgamma_check)))
print("Is dbeta correct? {}".format(np.allclose(dbeta, dbeta_check)))
# Out:
# WARNING:tensorflow:From C:\Users\Alokik\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Is a2_bn correct? True
# Is da2 correct? True
# Is dgamma correct? True
# Is dbeta correct? True

# %% [markdown]
# ### Experiments with MLP

# %% [markdown]
# **Experiment on shallow MLP**

# %%
use_bn = False
model = MLP(input_dim=3072, hidden_dims=[100], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_shallow_no_bn contains loss, train acc and valid acc history.
hist_shallow_no_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=2e-4, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.286, new learning rate = 0.00019
# epoch 2: valid acc = 0.358, new learning rate = 0.0001805
# epoch 3: valid acc = 0.36, new learning rate = 0.00017147499999999998
# epoch 4: valid acc = 0.366, new learning rate = 0.00016290124999999997
# epoch 5: valid acc = 0.36, new learning rate = 0.00015475618749999996
# epoch 6: valid acc = 0.37, new learning rate = 0.00014701837812499996
# epoch 7: valid acc = 0.356, new learning rate = 0.00013966745921874994
# epoch 8: valid acc = 0.366, new learning rate = 0.00013268408625781244
# epoch 9: valid acc = 0.372, new learning rate = 0.0001260498819449218
# epoch 10: valid acc = 0.382, new learning rate = 0.00011974738784767572
# epoch 11: valid acc = 0.37, new learning rate = 0.00011376001845529192
# epoch 12: valid acc = 0.356, new learning rate = 0.00010807201753252733
# epoch 13: valid acc = 0.348, new learning rate = 0.00010266841665590096
# epoch 14: valid acc = 0.382, new learning rate = 9.75349958231059e-05
# epoch 15: valid acc = 0.368, new learning rate = 9.265824603195061e-05
# epoch 16: valid acc = 0.36, new learning rate = 8.802533373035307e-05
# epoch 17: valid acc = 0.362, new learning rate = 8.362406704383542e-05
# epoch 18: valid acc = 0.378, new learning rate = 7.944286369164364e-05
# epoch 19: valid acc = 0.376, new learning rate = 7.547072050706145e-05
# epoch 20: valid acc = 0.372, new learning rate = 7.169718448170838e-05
# epoch 21: valid acc = 0.366, new learning rate = 6.811232525762296e-05
# epoch 22: valid acc = 0.358, new learning rate = 6.470670899474181e-05
# epoch 23: valid acc = 0.358, new learning rate = 6.147137354500471e-05
# epoch 24: valid acc = 0.36, new learning rate = 5.839780486775447e-05
# epoch 25: valid acc = 0.372, new learning rate = 5.547791462436675e-05
# epoch 26: valid acc = 0.362, new learning rate = 5.270401889314841e-05
# epoch 27: valid acc = 0.364, new learning rate = 5.0068817948490985e-05
# epoch 28: valid acc = 0.37, new learning rate = 4.756537705106643e-05
# epoch 29: valid acc = 0.366, new learning rate = 4.518710819851311e-05
# epoch 30: valid acc = 0.364, new learning rate = 4.292775278858745e-05
# epoch 31: valid acc = 0.364, new learning rate = 4.078136514915808e-05
# epoch 32: valid acc = 0.364, new learning rate = 3.874229689170017e-05
# epoch 33: valid acc = 0.36, new learning rate = 3.680518204711516e-05
# epoch 34: valid acc = 0.366, new learning rate = 3.49649229447594e-05
# epoch 35: valid acc = 0.364, new learning rate = 3.321667679752143e-05
# epoch 36: valid acc = 0.358, new learning rate = 3.1555842957645355e-05
# epoch 37: valid acc = 0.358, new learning rate = 2.9978050809763088e-05
# epoch 38: valid acc = 0.358, new learning rate = 2.8479148269274933e-05
# epoch 39: valid acc = 0.358, new learning rate = 2.7055190855811184e-05
# epoch 40: valid acc = 0.358, new learning rate = 2.5702431313020624e-05
# epoch 41: valid acc = 0.358, new learning rate = 2.4417309747369593e-05
# epoch 42: valid acc = 0.358, new learning rate = 2.319644426000111e-05
# epoch 43: valid acc = 0.358, new learning rate = 2.2036622047001054e-05
# epoch 44: valid acc = 0.358, new learning rate = 2.0934790944651e-05
# epoch 45: valid acc = 0.358, new learning rate = 1.988805139741845e-05
# epoch 46: valid acc = 0.36, new learning rate = 1.8893648827547526e-05
# epoch 47: valid acc = 0.358, new learning rate = 1.7948966386170148e-05
# epoch 48: valid acc = 0.356, new learning rate = 1.705151806686164e-05
# epoch 49: valid acc = 0.356, new learning rate = 1.619894216351856e-05
# epoch 50: valid acc = 0.356, new learning rate = 1.538899505534263e-05

# %%
# Build a two-layer netowrk with batch normalization.
use_bn = True
model = MLP(input_dim=3072, hidden_dims=[100], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_shallow_no_bn contains loss, train acc and valid acc history.
hist_shallow_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=2e-4, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.182, new learning rate = 0.00019
# epoch 2: valid acc = 0.17, new learning rate = 0.0001805
# epoch 3: valid acc = 0.178, new learning rate = 0.00017147499999999998
# epoch 4: valid acc = 0.192, new learning rate = 0.00016290124999999997
# epoch 5: valid acc = 0.188, new learning rate = 0.00015475618749999996
# epoch 6: valid acc = 0.202, new learning rate = 0.00014701837812499996
# epoch 7: valid acc = 0.22, new learning rate = 0.00013966745921874994
# epoch 8: valid acc = 0.23, new learning rate = 0.00013268408625781244
# epoch 9: valid acc = 0.23, new learning rate = 0.0001260498819449218
# epoch 10: valid acc = 0.224, new learning rate = 0.00011974738784767572
# epoch 11: valid acc = 0.226, new learning rate = 0.00011376001845529192
# epoch 12: valid acc = 0.224, new learning rate = 0.00010807201753252733
# epoch 13: valid acc = 0.228, new learning rate = 0.00010266841665590096
# epoch 14: valid acc = 0.23, new learning rate = 9.75349958231059e-05
# epoch 15: valid acc = 0.23, new learning rate = 9.265824603195061e-05
# epoch 16: valid acc = 0.23, new learning rate = 8.802533373035307e-05
# epoch 17: valid acc = 0.234, new learning rate = 8.362406704383542e-05
# epoch 18: valid acc = 0.24, new learning rate = 7.944286369164364e-05
# epoch 19: valid acc = 0.238, new learning rate = 7.547072050706145e-05
# epoch 20: valid acc = 0.238, new learning rate = 7.169718448170838e-05
# epoch 21: valid acc = 0.238, new learning rate = 6.811232525762296e-05
# epoch 22: valid acc = 0.242, new learning rate = 6.470670899474181e-05
# epoch 23: valid acc = 0.24, new learning rate = 6.147137354500471e-05
# epoch 24: valid acc = 0.24, new learning rate = 5.839780486775447e-05
# epoch 25: valid acc = 0.24, new learning rate = 5.547791462436675e-05
# epoch 26: valid acc = 0.24, new learning rate = 5.270401889314841e-05
# epoch 27: valid acc = 0.24, new learning rate = 5.0068817948490985e-05
# epoch 28: valid acc = 0.24, new learning rate = 4.756537705106643e-05
# epoch 29: valid acc = 0.238, new learning rate = 4.518710819851311e-05
# epoch 30: valid acc = 0.242, new learning rate = 4.292775278858745e-05
# epoch 31: valid acc = 0.244, new learning rate = 4.078136514915808e-05
# epoch 32: valid acc = 0.246, new learning rate = 3.874229689170017e-05
# epoch 33: valid acc = 0.246, new learning rate = 3.680518204711516e-05
# epoch 34: valid acc = 0.246, new learning rate = 3.49649229447594e-05
# epoch 35: valid acc = 0.248, new learning rate = 3.321667679752143e-05
# epoch 36: valid acc = 0.25, new learning rate = 3.1555842957645355e-05
# epoch 37: valid acc = 0.25, new learning rate = 2.9978050809763088e-05
# epoch 38: valid acc = 0.248, new learning rate = 2.8479148269274933e-05
# epoch 39: valid acc = 0.248, new learning rate = 2.7055190855811184e-05
# epoch 40: valid acc = 0.246, new learning rate = 2.5702431313020624e-05
# epoch 41: valid acc = 0.246, new learning rate = 2.4417309747369593e-05
# epoch 42: valid acc = 0.248, new learning rate = 2.319644426000111e-05
# epoch 43: valid acc = 0.25, new learning rate = 2.2036622047001054e-05
# epoch 44: valid acc = 0.248, new learning rate = 2.0934790944651e-05
# epoch 45: valid acc = 0.246, new learning rate = 1.988805139741845e-05
# epoch 46: valid acc = 0.246, new learning rate = 1.8893648827547526e-05
# epoch 47: valid acc = 0.246, new learning rate = 1.7948966386170148e-05
# epoch 48: valid acc = 0.246, new learning rate = 1.705151806686164e-05
# epoch 49: valid acc = 0.246, new learning rate = 1.619894216351856e-05
# epoch 50: valid acc = 0.246, new learning rate = 1.538899505534263e-05

# %%
# Plot both results together and make a comparison. 
plt.clf()
title_name = ["loss", "train acc", "val acc"]
_, axarr = plt.subplots(1,3, figsize=(15,5))
for i in range(3):
    axarr[i].plot(hist_shallow_no_bn[i], label="no_bn")
    axarr[i].plot(hist_shallow_bn[i], label="bn")
    axarr[i].legend(), axarr[i].set_title(title_name[i])
plt.show()

# %% [markdown]
# **Experiment on deep MLP**

# %%
use_bn = False
model = MLP(input_dim=3072, hidden_dims=[100, 50, 50, 50], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_deep_no_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=3e-4, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.102, new learning rate = 0.000285
# epoch 2: valid acc = 0.134, new learning rate = 0.00027075
# epoch 3: valid acc = 0.18, new learning rate = 0.0002572125
# epoch 4: valid acc = 0.176, new learning rate = 0.000244351875
# epoch 5: valid acc = 0.176, new learning rate = 0.00023213428124999998
# epoch 6: valid acc = 0.176, new learning rate = 0.00022052756718749997
# epoch 7: valid acc = 0.17, new learning rate = 0.00020950118882812497
# epoch 8: valid acc = 0.172, new learning rate = 0.00019902612938671872
# epoch 9: valid acc = 0.178, new learning rate = 0.00018907482291738277
# epoch 10: valid acc = 0.176, new learning rate = 0.0001796210817715136
# epoch 11: valid acc = 0.176, new learning rate = 0.00017064002768293793
# epoch 12: valid acc = 0.174, new learning rate = 0.00016210802629879103
# epoch 13: valid acc = 0.168, new learning rate = 0.00015400262498385146
# epoch 14: valid acc = 0.17, new learning rate = 0.00014630249373465888
# epoch 15: valid acc = 0.17, new learning rate = 0.00013898736904792593
# epoch 16: valid acc = 0.17, new learning rate = 0.00013203800059552963
# epoch 17: valid acc = 0.172, new learning rate = 0.00012543610056575314
# epoch 18: valid acc = 0.166, new learning rate = 0.00011916429553746547
# epoch 19: valid acc = 0.17, new learning rate = 0.0001132060807605922
# epoch 20: valid acc = 0.162, new learning rate = 0.00010754577672256258
# epoch 21: valid acc = 0.166, new learning rate = 0.00010216848788643445
# epoch 22: valid acc = 0.174, new learning rate = 9.706006349211273e-05
# epoch 23: valid acc = 0.184, new learning rate = 9.220706031750709e-05
# epoch 24: valid acc = 0.184, new learning rate = 8.759670730163173e-05
# epoch 25: valid acc = 0.178, new learning rate = 8.321687193655014e-05
# epoch 26: valid acc = 0.182, new learning rate = 7.905602833972263e-05
# epoch 27: valid acc = 0.176, new learning rate = 7.510322692273649e-05
# epoch 28: valid acc = 0.172, new learning rate = 7.134806557659966e-05
# epoch 29: valid acc = 0.166, new learning rate = 6.778066229776968e-05
# epoch 30: valid acc = 0.162, new learning rate = 6.43916291828812e-05
# epoch 31: valid acc = 0.164, new learning rate = 6.117204772373713e-05
# epoch 32: valid acc = 0.168, new learning rate = 5.811344533755027e-05
# epoch 33: valid acc = 0.162, new learning rate = 5.520777307067275e-05
# epoch 34: valid acc = 0.16, new learning rate = 5.244738441713911e-05
# epoch 35: valid acc = 0.154, new learning rate = 4.982501519628216e-05
# epoch 36: valid acc = 0.16, new learning rate = 4.733376443646805e-05
# epoch 37: valid acc = 0.156, new learning rate = 4.496707621464464e-05
# epoch 38: valid acc = 0.16, new learning rate = 4.2718722403912406e-05
# epoch 39: valid acc = 0.154, new learning rate = 4.0582786283716785e-05
# epoch 40: valid acc = 0.158, new learning rate = 3.855364696953094e-05
# epoch 41: valid acc = 0.15, new learning rate = 3.6625964621054396e-05
# epoch 42: valid acc = 0.164, new learning rate = 3.479466639000167e-05
# epoch 43: valid acc = 0.166, new learning rate = 3.3054933070501586e-05
# epoch 44: valid acc = 0.164, new learning rate = 3.14021864169765e-05
# epoch 45: valid acc = 0.16, new learning rate = 2.9832077096127674e-05
# epoch 46: valid acc = 0.158, new learning rate = 2.834047324132129e-05
# epoch 47: valid acc = 0.164, new learning rate = 2.6923449579255225e-05
# epoch 48: valid acc = 0.172, new learning rate = 2.5577277100292462e-05
# epoch 49: valid acc = 0.166, new learning rate = 2.4298413245277838e-05
# epoch 50: valid acc = 0.166, new learning rate = 2.3083492583013945e-05

# %%
use_bn = True
model = MLP(input_dim=3072, hidden_dims=[100, 50, 50, 50], num_classes=10, 
            weight_scale=1e-3, l2_reg=0.0, use_bn=use_bn)
optimizer = AdamOptim(model)
# hist_no_dropout contains loss, train acc and valid acc history.
hist_deep_bn = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=50, batch_size=100, learning_rate=3e-4, learning_decay=0.95, 
                           verbose=False, record_interval = 4)
# Out:
# number of batches for training: 20
# epoch 1: valid acc = 0.12, new learning rate = 0.000285
# epoch 2: valid acc = 0.16, new learning rate = 0.00027075
# epoch 3: valid acc = 0.158, new learning rate = 0.0002572125
# epoch 4: valid acc = 0.162, new learning rate = 0.000244351875
# epoch 5: valid acc = 0.16, new learning rate = 0.00023213428124999998
# epoch 6: valid acc = 0.16, new learning rate = 0.00022052756718749997
# epoch 7: valid acc = 0.166, new learning rate = 0.00020950118882812497
# epoch 8: valid acc = 0.166, new learning rate = 0.00019902612938671872
# epoch 9: valid acc = 0.164, new learning rate = 0.00018907482291738277
# epoch 10: valid acc = 0.168, new learning rate = 0.0001796210817715136
# epoch 11: valid acc = 0.166, new learning rate = 0.00017064002768293793
# epoch 12: valid acc = 0.168, new learning rate = 0.00016210802629879103
# epoch 13: valid acc = 0.168, new learning rate = 0.00015400262498385146
# epoch 14: valid acc = 0.164, new learning rate = 0.00014630249373465888
# epoch 15: valid acc = 0.166, new learning rate = 0.00013898736904792593
# epoch 16: valid acc = 0.158, new learning rate = 0.00013203800059552963
# epoch 17: valid acc = 0.16, new learning rate = 0.00012543610056575314
# epoch 18: valid acc = 0.158, new learning rate = 0.00011916429553746547
# epoch 19: valid acc = 0.16, new learning rate = 0.0001132060807605922
# epoch 20: valid acc = 0.158, new learning rate = 0.00010754577672256258
# epoch 21: valid acc = 0.158, new learning rate = 0.00010216848788643445
# epoch 22: valid acc = 0.158, new learning rate = 9.706006349211273e-05
# epoch 23: valid acc = 0.158, new learning rate = 9.220706031750709e-05
# epoch 24: valid acc = 0.158, new learning rate = 8.759670730163173e-05
# epoch 25: valid acc = 0.158, new learning rate = 8.321687193655014e-05
# epoch 26: valid acc = 0.158, new learning rate = 7.905602833972263e-05
# epoch 27: valid acc = 0.158, new learning rate = 7.510322692273649e-05
# epoch 28: valid acc = 0.158, new learning rate = 7.134806557659966e-05
# epoch 29: valid acc = 0.158, new learning rate = 6.778066229776968e-05
# epoch 30: valid acc = 0.162, new learning rate = 6.43916291828812e-05
# epoch 31: valid acc = 0.162, new learning rate = 6.117204772373713e-05
# epoch 32: valid acc = 0.162, new learning rate = 5.811344533755027e-05
# epoch 33: valid acc = 0.162, new learning rate = 5.520777307067275e-05
# epoch 34: valid acc = 0.162, new learning rate = 5.244738441713911e-05
# epoch 35: valid acc = 0.164, new learning rate = 4.982501519628216e-05
# epoch 36: valid acc = 0.164, new learning rate = 4.733376443646805e-05
# epoch 37: valid acc = 0.164, new learning rate = 4.496707621464464e-05
# epoch 38: valid acc = 0.162, new learning rate = 4.2718722403912406e-05
# epoch 39: valid acc = 0.162, new learning rate = 4.0582786283716785e-05
# epoch 40: valid acc = 0.162, new learning rate = 3.855364696953094e-05
# epoch 41: valid acc = 0.162, new learning rate = 3.6625964621054396e-05
# epoch 42: valid acc = 0.16, new learning rate = 3.479466639000167e-05
# epoch 43: valid acc = 0.16, new learning rate = 3.3054933070501586e-05
# epoch 44: valid acc = 0.16, new learning rate = 3.14021864169765e-05
# epoch 45: valid acc = 0.16, new learning rate = 2.9832077096127674e-05
# epoch 46: valid acc = 0.16, new learning rate = 2.834047324132129e-05
# epoch 47: valid acc = 0.16, new learning rate = 2.6923449579255225e-05
# epoch 48: valid acc = 0.16, new learning rate = 2.5577277100292462e-05
# epoch 49: valid acc = 0.16, new learning rate = 2.4298413245277838e-05
# epoch 50: valid acc = 0.16, new learning rate = 2.3083492583013945e-05

# %%
# Plot both results together and make a comparison.
plt.clf()
title_name = ["loss", "train acc", "val acc"]
_, axarr = plt.subplots(1,3, figsize=(15,5))
for i in range(3):
    axarr[i].plot(hist_deep_no_bn[i], label="no_bn")
    axarr[i].plot(hist_deep_bn[i], label="bn")
    axarr[i].legend(), axarr[i].set_title(title_name[i])
plt.show()
